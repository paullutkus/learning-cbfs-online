# %%
import numpy as np
import matplotlib.pyplot as plt
from data import make_rectangle, insert_shape, plot_data
from agent import Agent
from optim import cas_train_cbf
from utils import plot_cbf

# %load_ext autoreload
# %autoreload 2

# %%
grid, obs_dict = make_rectangle(height=15, width=15, density=10, unsafe_margin=0.3, center=(0,0))
#obs_dict = insert_shape(np.array([-0.2, 2.3]), grid, obs_dict, shape='triangle', scale=3.2, theta=-np.pi/8)
obs_dict = insert_shape(np.array([0, 3.3]), grid, obs_dict, shape='circle', scale=2, theta=0)
c_grid, c_obs_dict= make_rectangle(height=15, width=15, density=5, unsafe_margin=0  , center=(0,0))
plot_data(grid, obs_dict)
plot_data(c_grid, c_obs_dict)

# %%
a = Agent((0, 0), grid, obs_dict, sensor_radius=3)

scan_safe, scan_unsafe = a.scan()
rx = 4
samples  = a.sample(rx)

if scan_unsafe.shape[0] != 0:
    x_unsafe = np.vstack((scan_unsafe, samples))
else: 
    x_unsafe = samples

n_safe = scan_safe.shape[0]
x_buffer, x_safe = a.make_buffer(scan_safe, int(0.2 * n_safe), 0.50)

rc = 3
C = []
for x in c_grid:
    if np.linalg.norm(x - a.pos) <= rc:
        C.append(x)
C = np.array(C)
a.centers.append(C)

# %%
plot_data(grid, obs_dict, [(x_safe  , "cyan"), 
                           (x_buffer, "blue"), 
                           (x_unsafe, "red"),
                           (C       , "green")])

# %%
theta_max=10
max_elem =100
gamma_safe=0.3
gamma_unsafe=-0.3
gamma_dyn=0.1
theta=cas_train_cbf(x_safe, x_buffer, x_unsafe, C, theta_max, max_elem, rx, rc, gamma_safe, gamma_unsafe, gamma_dyn)
a.thetas.append(theta)
# Out:
# 1.512613632095123
# CasADi - 2024-03-23 19:34:40 MESSAGE("nlp::init") [.../casadi/core/function_internal.cpp:547]
# CasADi - 2024-03-23 19:34:40 MESSAGE("nlp::init") [.../casadi/core/x_function.hpp:327]
# CasADi - 2024-03-23 19:34:40 MESSAGE("nlp::init") [.../casadi/core/mx_function.cpp:113]
# CasADi - 2024-03-23 19:34:40 MESSAGE("Using live variables: work array is 7 instead of 5482") [.../casadi/core/mx_function.cpp:326]
# CasADi - 2024-03-23 19:34:41 MESSAGE("solver::init") [.../casadi/core/function_internal.cpp:547]
# CasADi - 2024-03-23 19:34:41 MESSAGE("solver::create_function nlp_grad:[x, p, lam:f, lam:g]->[f, g, grad:gamma:x, grad:gamma:p]") [.../casadi/core/oracle_function.cpp:219]
# CasADi - 2024-03-23 19:34:41 MESSAGE("solver::create_function nlp_f:[x, p]->[f]") [.../casadi/core/oracle_function.cpp:219]
# CasADi - 2024-03-23 19:34:41 MESSAGE("solver::create_function nlp_g:[x, p]->[g]") [.../casadi/core/oracle_function.cpp:219]
# CasADi - 2024-03-23 19:34:41 MESSAGE("solver::create_function nlp_grad_f:[x, p]->[f, grad:f:x]") [.../casadi/core/oracle_function.cpp:219]
# CasADi - 2024-03-23 19:34:41 MESSAGE("solver::create_function nlp_jac_g:[x, p]->[g, jac:g:x]") [.../casadi/core/oracle_function.cpp:219]
# CasADi - 2024-03-23 19:34:46 MESSAGE("solver::create_function nlp_hess_l:[x, p, lam:f, lam:g]->[triu:hess:gamma:x:x]") [.../casadi/core/oracle_function.cpp:219]
# There are 129 variables and 608 constraints.
# Using exact Hessian
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.14
#   56  1.7554664e+03 4.62e+00 7.55e+02  -1.0 7.12e+01    -  2.50e-02 7.61e-01f  1
#   57  1.6813171e+03 3.92e+00 7.03e+02  -1.0 3.07e+01    -  4.48e-02 7.43e-02f  1
#   58  1.5549743e+03 3.11e+00 6.23e+02  -1.0 3.41e+01    -  1.15e-01 1.13e-01f  1
#   59  1.1897942e+03 2.14e+00 4.43e+02  -1.0 3.76e+01    -  1.61e-01 3.13e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   60  4.3765914e+02 0.00e+00 3.28e+01  -1.0 4.47e+01    -  3.09e-01 1.00e+00f  1
#   61  1.9882042e+02 0.00e+00 5.86e+01  -1.0 3.44e+01    -  6.72e-01 1.00e+00f  1
#   62  1.0635625e+02 0.00e+00 1.14e+01  -1.0 2.24e+01    -  8.31e-01 1.00e+00f  1
#   63  7.4453587e+01 0.00e+00 9.99e-02  -1.0 2.20e+01    -  9.74e-01 1.00e+00f  1
#   64  6.8663633e+01 0.00e+00 2.51e+00  -1.0 2.22e+01    -  9.12e-01 3.74e-01f  1
#   65  6.2705403e+01 0.00e+00 1.38e+00  -1.0 1.68e+01    -  1.00e+00 5.75e-01f  1
#   66  6.2139915e+01 0.00e+00 1.20e-03  -1.0 5.79e+00    -  1.00e+00 1.00e+00f  1
#   67  6.0376118e+01 0.00e+00 1.51e+00  -1.7 7.54e+00    -  1.00e+00 6.52e-01f  1
#   68  6.0003275e+01 0.00e+00 2.18e-04  -1.7 2.88e+00    -  1.00e+00 1.00e+00h  1
#   69  5.9831883e+01 0.00e+00 1.76e-01  -3.8 1.86e+00    -  9.80e-01 8.30e-01h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   70  5.9818714e+01 0.00e+00 1.23e-06  -3.8 3.08e-01    -  1.00e+00 1.00e+00h  1
#   71  5.9817448e+01 0.00e+00 3.88e-09  -5.7 1.44e-02    -  1.00e+00 1.00e+00h  1
#   72  5.9817435e+01 0.00e+00 5.93e-13  -8.6 1.75e-04    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 72
#
#                                    (scaled)                 (unscaled)
# Objective...............:   5.9817434517385088e+01    5.9817434517385088e+01
# Dual infeasibility......:   5.9263705054490856e-13    5.9263705054490856e-13
# Constraint violation....:   0.0000000000000000e+00    0.0000000000000000e+00
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   2.5184678124496071e-09    2.5184678124496071e-09
# Overall NLP error.......:   2.5184678124496071e-09    2.5184678124496071e-09
#
#
# Number of objective function evaluations             = 81
# Number of objective gradient evaluations             = 72
# Number of equality constraint evaluations            = 0
# Number of inequality constraint evaluations          = 81
# Number of equality constraint Jacobian evaluations   = 0
# Number of inequality constraint Jacobian evaluations = 75
# Number of Lagrangian Hessian evaluations             = 72
# Total seconds in IPOPT                               = 8.726
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  10.66ms (131.59us) 660.48us (  8.15us)        81
#        nlp_g  |   3.86 s ( 47.61ms) 242.85ms (  3.00ms)        81
#   nlp_grad_f  |  10.43ms (142.90us) 654.64us (  8.97us)        73
#   nlp_hess_l  |  59.80 s (854.24ms)   3.78 s ( 53.97ms)        70
#    nlp_jac_g  |   5.39 s ( 70.93ms) 341.58ms (  4.49ms)        76
#        total  | 136.95 s (136.95 s)   8.73 s (  8.73 s)         1

# %%
plot_cbf(a.thetas, a.centers)

# %%
pos = 0
neg = 0
for elem in theta:
    if elem < 0:
        neg += elem
    else:
        pos += elem
print(neg/pos)
# Out:
# -1.3047596121620613

# %%
a.goto(np.array([0, 6.66]), tend=300)
# Out:
# position is (0, 0)
# h is [26.58255469]
# start time is 0
# new position is [0.         0.58164139]
# h is now [18.15883322]
# new time is 100
