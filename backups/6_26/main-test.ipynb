# %%
import numpy             as np
import matplotlib.pyplot as plt
import hj_reachability   as hj

from data      import make_rectangle, insert_shape, plot_data
from agent     import Agent
from tst_optim import cas_train_cbf, get_h
from utils     import plot_cbf

from timeit import default_timer as timer

# %load_ext autoreload
# %autoreload 2

# %%
#########################
### Data Construction ###
#########################

# grid parameters 
width         = 3
unsafe_margin = 0.3

# main grid -- unsafe_margin defines wall obstacles
grid, obs_dict = make_rectangle(height=width, width=width, density=150, unsafe_margin=unsafe_margin, center=(0,0))

# generate two circular obstacles
obs_dict = insert_shape(np.array([0,  0.75]), grid, obs_dict, shape='circle', scale=0.5, theta=0)
obs_dict = insert_shape(np.array([0, -0.75]), grid, obs_dict, shape='circle', scale=0.5, theta=0)

# supplementary grids for [c]enters and unsafe [s]amples
c_grid, c_obs_dict = make_rectangle(height=width, width=width, density=150, unsafe_margin=unsafe_margin, center=(0,0))
s_grid, s_obs_dict = make_rectangle(height=width, width=width, density=35 , unsafe_margin=unsafe_margin, center=(0,0))

# show the created grids
plot_data(  grid,   obs_dict)
plot_data(c_grid, c_obs_dict)
plot_data(s_grid, s_obs_dict)

# %%
###########################
### Agent Configuration ###
###########################

dynamics = hj.systems.Planar()
bf = 31   # csrbf order
b  = 0   # offset 
s  = 0.66 # csrbf zeroing
sensor_radius = 1
rx = 1.5 # sample radius
nm = 0.2 # nm * n_safe = number of neighbors to consider
p  = 0.6 # num neighber percentile under which boundary
rc = 1   # radius around scan in which centers are chosen

# make agent
a = Agent(dynamics, np.array([0, 0]), grid, obs_dict, width=width, 
                                            sensor_radius=1, 
                                            bf = bf, 
                                            b = b, 
                                            s = s)

# %%
############################
### Scan for initial CBF ###
############################

# scan for obstacles and generate unsafe samples
scan_safe, scan_unsafe = a.scan()
samples  = a.sample(rx, grid=s_grid)
if scan_unsafe.shape[0] != 0:
    x_unsafe = np.vstack((scan_unsafe, samples))
else: # in case no obstacles detected
    x_unsafe = samples

# create buffer region
n_safe = scan_safe.shape[0]
x_buffer, x_safe = a.make_buffer(scan_safe, int(nm * n_safe), p)

# collect centers within rc from c_grid
C = []
for x in c_grid:
    if np.linalg.norm(x - a.pos) <= rc:
        C.append(x)
C = np.array(C)
print(C.shape)
a.centers.append(C)
# Out:
# (437, 2)

# %%
#############################
### Plot initial CBF data ###
#############################

plot_data(grid, obs_dict, [(x_safe  , "cyan"  , 'o'), 
                           (x_buffer, "blue"  , 'o'), 
                           (x_unsafe, "red"   , 'o'),
                           (C       , "white" , '2')])

# %%
##############################
### Initial CBF Parameters ###
##############################

theta_max    = 10
max_elem     = 100
gamma_safe   = 0.3
gamma_unsafe = 0
gamma_dyn    = 0.1
lam_dh       = 10

# %%
#########################
### Solve Initial CBF ###
#########################

# get h as a function of agent parameter
h = get_h(a)

start = timer()
theta=cas_train_cbf(a, x_safe, x_buffer, x_unsafe, gamma_safe, gamma_dyn, gamma_unsafe, lam_dh=lam_dh, verbose=True)
elapsed_time = timer() - start
print("time:", elapsed_time)

a.thetas.append(theta)
a.rectify_c_and_theta()
# Out:
# CasADi - 2024-06-24 10:57:56 MESSAGE("nlp::init") [.../casadi/core/function_internal.cpp:547]
# CasADi - 2024-06-24 10:57:56 MESSAGE("nlp::init") [.../casadi/core/x_function.hpp:327]
# CasADi - 2024-06-24 10:57:56 MESSAGE("nlp::init") [.../casadi/core/mx_function.cpp:113]
# CasADi - 2024-06-24 10:57:56 MESSAGE("Using live variables: work array is 10 instead of 8577") [.../casadi/core/mx_function.cpp:326]
# CasADi - 2024-06-24 10:57:57 MESSAGE("solver::init") [.../casadi/core/function_internal.cpp:547]
# CasADi - 2024-06-24 10:57:57 MESSAGE("solver::create_function nlp_grad:[x, p, lam:f, lam:g]->[f, g, grad:gamma:x, grad:gamma:p]") [.../casadi/core/oracle_function.cpp:219]
# CasADi - 2024-06-24 10:57:57 MESSAGE("solver::create_function nlp_f:[x, p]->[f]") [.../casadi/core/oracle_function.cpp:219]
# CasADi - 2024-06-24 10:57:57 MESSAGE("solver::create_function nlp_g:[x, p]->[g]") [.../casadi/core/oracle_function.cpp:219]
# CasADi - 2024-06-24 10:57:57 MESSAGE("solver::create_function nlp_grad_f:[x, p]->[f, grad:f:x]") [.../casadi/core/oracle_function.cpp:219]
# CasADi - 2024-06-24 10:57:58 MESSAGE("solver::create_function nlp_jac_g:[x, p]->[g, jac:g:x]") [.../casadi/core/oracle_function.cpp:219]
# CasADi - 2024-06-24 10:58:06 MESSAGE("solver::create_function nlp_hess_l:[x, p, lam:f, lam:g]->[triu:hess:gamma:x:x]") [.../casadi/core/oracle_function.cpp:219]
# There are 437 variables and 671 constraints.
# Using exact Hessian
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.14.11, running with linear solver MUMPS 5.4.1.
#
# Number of nonzeros in equality constraint Jacobian...:        0
# Number of nonzeros in inequality constraint Jacobian.:    81137
# Number of nonzeros in Lagrangian Hessian.............:    71335
#
# Total number of variables............................:      437
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:        0
# Total number of inequality constraints...............:      671
#         inequality constraints with only lower bounds:      385
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:      286
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  1.7019575e+02 2.23e-01 2.36e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  1.7004048e+02 2.23e-01 2.95e+01  -1.0 2.30e-01   2.0 1.00e+00 4.31e-02h  1
#    2  1.7108739e+02 2.22e-01 1.04e+02  -1.0 1.97e+00   1.5 1.53e-02 5.09e-03h  1
#    3  1.7125321e+02 2.22e-01 1.17e+04  -1.0 2.54e+00   2.9 5.17e-02 1.05e-03h  1
#    4  1.7695169e+02 2.18e-01 1.18e+04  -1.0 2.29e+00   2.4 2.49e-02 1.91e-02h  1
#    5  1.7728894e+02 2.17e-01 1.20e+04  -1.0 4.82e+00   1.9 1.60e-02 1.30e-03h  1
#    6  1.7932120e+02 2.16e-01 1.19e+04  -1.0 1.73e+01   1.4 7.36e-03 7.60e-03f  1
#    7  1.7967831e+02 2.15e-01 1.25e+04  -1.0 9.73e+00   2.7 6.60e-03 1.13e-03h  1
#    8  1.8017413e+02 2.15e-01 3.10e+04  -1.0 9.26e+00   3.2 5.63e-03 1.49e-03f  1
#    9  1.8056892e+02 2.15e-01 9.60e+04  -1.0 1.33e+01   3.6 6.53e-03 1.11e-03h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  1
#   34  2.7372114e+03 0.00e+00 7.44e-01  -1.0 1.98e-01    -  1.00e+00 1.00e+00f  1
#   35  2.7352368e+03 0.00e+00 1.15e+02  -1.7 1.17e+00    -  4.06e-01 1.60e-01f  1
#   36  2.7317000e+03 0.00e+00 9.75e+01  -1.7 3.44e-01    -  1.00e+00 6.56e-01f  1
#   37  2.7302722e+03 0.00e+00 1.35e-02  -1.7 9.48e-02    -  1.00e+00 1.00e+00f  1
#   38  2.7294532e+03 0.00e+00 1.06e+01  -3.8 6.18e-02    -  9.97e-01 9.41e-01f  1
#   39  2.7294132e+03 0.00e+00 5.39e-05  -3.8 2.11e-02    -  1.00e+00 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   40  2.7294080e+03 0.00e+00 6.70e-07  -5.7 4.24e-03    -  1.00e+00 1.00e+00h  1
#   41  2.7294080e+03 0.00e+00 3.11e-10  -5.7 1.99e-04    -  1.00e+00 1.00e+00h  1
#   42  2.7294080e+03 0.00e+00 2.09e-11  -8.6 1.18e-05    -  1.00e+00 1.00e+00f  1
#
# Number of Iterations....: 42
#
#                                    (scaled)                 (unscaled)
# Objective...............:   2.7294079579206655e+03    2.7294079579206655e+03
# Dual infeasibility......:   2.0862533922638704e-11    2.0862533922638704e-11
# Constraint violation....:   0.0000000000000000e+00    0.0000000000000000e+00
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   2.9210818797224339e-09    2.9210818797224339e-09
# Overall NLP error.......:   2.9210818797224339e-09    2.9210818797224339e-09
#
#
# Number of objective function evaluations             = 47
# Number of objective gradient evaluations             = 41
# Number of equality constraint evaluations            = 0
# Number of inequality constraint evaluations          = 47
# Number of equality constraint Jacobian evaluations   = 0
# Number of inequality constraint Jacobian evaluations = 44
# Number of Lagrangian Hessian evaluations             = 42
# Total seconds in IPOPT                               = 5.150
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 182.18ms (  3.88ms)  11.70ms (248.96us)        47
#        nlp_g  |   1.02 s ( 21.62ms)  65.49ms (  1.39ms)        47
#   nlp_grad_f  | 311.85ms (  7.42ms)  20.56ms (489.43us)        42
#   nlp_hess_l  |  45.71 s (  1.11 s)   3.12 s ( 76.21ms)        41
#    nlp_jac_g  |   1.74 s ( 38.61ms) 114.47ms (  2.54ms)        45
#        total  |  73.93 s ( 73.93 s)   5.15 s (  5.15 s)         1
# time: 49.430703730962705
# centers shape before:
# (437, 2)

# %%
########################
### Plot Initial CBF ###
########################

start = timer()

plot_cbf(a, np.array(a.centers), np.array(a.thetas))

elapsed_time = timer() - start
print("time:", elapsed_time)
# Out:
# time: 13.559875759994611

# %%
##################################
### Configure Safe Exploration ###
##################################

tol  = 0.2 # h-value at which to halt approac
dx   = 0.5 # if |x'-x|<dx, approach again
tend = 50  # Duration of boundary approach
T    = 3   # MPC horizon (default timestep is 0.05)
N    = 30  # number of CBFs to learn

# %%
##########################
### Safe Exploration ###
##########################

for i in range(N):
    ######################
    ### Go to boundary ###
    ######################
    prev_pos = a.pos  
    while np.linalg.norm(a.pos - prev_pos) <= tol:    
        target=a.width*(1+unsafe_margin)*(np.random.rand(2)-0.5)  
        while h(target, np.array(a.centers), np.array(a.thetas))[0] > 0:
            target=a.width*(1+unsafe_margin)*(np.random.rand(2)-0.5)
        print("target:", target) 
        a.goto(target, T=T, tend=tend, tol=tol) 
        print("dx:", np.linalg.norm(a.pos - prev_pos))

    ####################
    ### Collect data ###
    ####################
    # unsafe data:
    scan_safe, scan_unsafe = a.scan()
    samples  = a.sample(rx, grid=s_grid) 
    if scan_unsafe.shape[0] != 0:
        x_unsafe = np.vstack((scan_unsafe, samples))
    else: 
        x_unsafe = samples 
    # safe and buffer data:
    n_safe = scan_safe.shape[0]
    x_buffer, x_safe = a.make_buffer(scan_safe, int(nm * n_safe), p)
    C  = [] 
    # centers:
    for x in c_grid:
        if np.linalg.norm(x - a.pos) <= rc:
            C.append(x)
    C = np.array(C)
    a.centers.append(C)
    plot_data(grid, obs_dict, [(x_safe  , "cyan"  , 'o'), 
                               (x_buffer, "blue"  , 'o'), 
                               (x_unsafe, "red"   , 'o'),
                               (C       , "white" , '2')])
    #####################
    ### Learn new CBF ###
    #####################
    theta=cas_train_cbf(a, x_safe, x_buffer, x_unsafe, gamma_safe, gamma_unsafe, gamma_dyn, lam_dh=lam_dh, verbose=True)
    a.thetas.append(theta)
    a.rectify_c_and_theta()
    plot_cbf(a, np.array(a.centers), np.array(a.thetas))
# Out:
# target: [1.61556331 1.86768885]
# target in goto [1.61556331 1.86768885]
# position is [0 0]
# h is 0.2745658493693133
# start time is 0
# new position is [0.70290754 0.41445038]
# h is now 0.20000000000000004
# new time is 50
# dx: 0.8159951768937497
# CasADi - 2024-06-24 10:59:41 MESSAGE("nlp::init") [.../casadi/core/function_internal.cpp:547]
# CasADi - 2024-06-24 10:59:41 MESSAGE("nlp::init") [.../casadi/core/x_function.hpp:327]
# CasADi - 2024-06-24 10:59:41 MESSAGE("nlp::init") [.../casadi/core/mx_function.cpp:113]
# CasADi - 2024-06-24 10:59:41 MESSAGE("Using live variables: work array is 10 instead of 9584") [.../casadi/core/mx_function.cpp:326]
# CasADi - 2024-06-24 10:59:41 MESSAGE("solver::init") [.../casadi/core/function_internal.cpp:547]
# CasADi - 2024-06-24 10:59:42 MESSAGE("solver::create_function nlp_grad:[x, p, lam:f, lam:g]->[f, g, grad:gamma:x, grad:gamma:p]") [.../casadi/core/oracle_function.cpp:219]
# CasADi - 2024-06-24 10:59:42 MESSAGE("solver::create_function nlp_f:[x, p]->[f]") [.../casadi/core/oracle_function.cpp:219]
# CasADi - 2024-06-24 10:59:42 MESSAGE("solver::create_function nlp_g:[x, p]->[g]") [.../casadi/core/oracle_function.cpp:219]
# CasADi - 2024-06-24 10:59:42 MESSAGE("solver::create_function nlp_grad_f:[x, p]->[f, grad:f:x]") [.../casadi/core/oracle_function.cpp:219]
# CasADi - 2024-06-24 10:59:42 MESSAGE("solver::create_function nlp_jac_g:[x, p]->[g, jac:g:x]") [.../casadi/core/oracle_function.cpp:219]
# CasADi - 2024-06-24 10:59:53 MESSAGE("solver::create_function nlp_hess_l:[x, p, lam:f, lam:g]->[triu:hess:gamma:x:x]") [.../casadi/core/oracle_function.cpp:219]
# There are 437 variables and 690 constraints.
# Using exact Hessian
# This is Ipopt version 3.14.11, running with linear solver MUMPS 5.4.1.
#
# Number of nonzeros in equality constraint Jacobian...:        0
# Number of nonzeros in inequality constraint Jacobian.
-05    -  1.00e+00 1.00e+00f  1
#
# Number of Iterations....: 25
#
#                                    (scaled)                 (unscaled)
# Objective...............:   1.0916948470321890e+03    1.0916948470321890e+03
# Dual infeasibility......:   5.6843418860808015e-14    5.6843418860808015e-14
# Constraint violation....:   0.0000000000000000e+00    0.0000000000000000e+00
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   3.1302453581351420e-09    3.1302453581351420e-09
# Overall NLP error.......:   3.1302453581351420e-09    3.1302453581351420e-09
#
#
# Number of objective function evaluations             = 26
# Number of objective gradient evaluations             = 26
# Number of equality constraint evaluations            = 0
# Number of inequality constraint evaluations          = 26
# Number of equality constraint Jacobian evaluations   = 0
# Number of inequality constraint Jacobian evaluations = 26
# Number of Lagrangian Hessian evaluations             = 25
# Total seconds in IPOPT                               = 3.106
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 147.76ms (  5.68ms)   9.53ms (366.71us)        26
#        nlp_g  | 648.21ms ( 24.93ms)  42.43ms (  1.63ms)        26
#   nlp_grad_f  | 285.33ms ( 10.57ms)  18.96ms (702.12us)        27
#   nlp_hess_l  |  27.90 s (  1.12 s)   2.18 s ( 87.12ms)        25
#    nlp_jac_g  |   1.66 s ( 61.54ms) 109.21ms (  4.04ms)        27
#        total  |  40.23 s ( 40.23 s)   3.11 s (  3.11 s)         1
# centers shape before:
# (437, 2)
# (437, 2)
# numc 437
# cmax before 437
# numc <= self.cmax
# Cnew shape before (437, 2)
# Cnew shape after (437, 2)
# theta shape before (437,)
# theta_shape after (437,)
# cmax after 437
# centers shape after
# (437, 2)
# (437, 2)
# target: [-1.8451729  -1.11079613]
# target in goto [-1.8451729  -1.11079613]
# position is [0.70290754 0.41445038]
# h is 0.28640586835961196
# start time is 50
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 15
#      13         target=a.width*(1+unsafe_margin)*(np.random.rand(2)-0.5)
#      14     print("target:", target)
# ---> 15     a.goto(target, T=T, tend=tend, tol=tol)
#      16     print("dx:", np.linalg.norm(a.pos - prev_pos))
#      18 ####################
#      19 ### Collect data ###
#      20 ####################
#      21 # unsafe data:
#
# File ~/Documents/cbf/online/csrbf_hjb_np_test/agent.py:166, in Agent.goto(self, target, T, tend, tol, use_cbf_mpc, theta)
#     164     plot_cbf(self, np.array(self.centers), np.array(self.thetas), traj=traj, target=target, theta=theta, obstacles=self.obstacles)
#     165 else:
# --> 166     plot_cbf(self, np.array(self.centers), np.array(self.thetas), traj=traj, target=target, obstacles=self.obstacles)
#     169 self.pos = traj[-1, :]
#     170 self.t  += tend
#
# File ~/Documents/cbf/online/csrbf_hjb_np_test/utils.py:70, in plot_cbf(a, centers, thetas, traj, target, obstacles, angle)
#      68             hvals[i,j], _ = h(np.array([x, y, angle]), centers, thetas)
#      69         else:
# ---> 70             hvals[i,j], _ = h(np.array([x, y]), centers, thetas)
#      72 #hvals = vmap(lambda s1: vmap(lambda s2: h_joint(jnp.array([s1, s2]), thetas, centers))(x2))(x1)
#      74 plt.rc('xtick', labelsize=14)
#
# File ~/Documents/cbf/online/csrbf_hjb_np_test/tst_optim.py:13, in get_h.<locals>.h(x, C, theta)
#      12 def h(x, C, theta):
# ---> 13     h_vec = np.einsum('ij,ij->i', phi(x, C, bf, s), theta)
#      14     i = np.argmax(h_vec)
#      15     return h_vec[i] + b, i
#
# KeyboardInterrupt:
